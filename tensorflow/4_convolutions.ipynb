# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
import cPickle as pickle
import numpy as np
import tensorflow as tf
# Out:
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 30 days
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 30 days

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print 'Training set', train_dataset.shape, train_labels.shape
  print 'Validation set', valid_dataset.shape, valid_labels.shape
  print 'Test set', test_dataset.shape, test_labels.shape
# Out:
# Training set (200000, 28, 28) (200000,)
# Validation set (10000, 28, 28) (10000,)
# Test set (18724, 28, 28) (18724,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print 'Training set', train_dataset.shape, train_labels.shape
print 'Validation set', valid_dataset.shape, valid_labels.shape
print 'Test set', test_dataset.shape, test_labels.shape
# Out:
# Training set (200000, 28, 28, 1) (200000, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (18724, 28, 28, 1) (18724, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size / 4 * image_size / 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print "Initialized"
  for step in xrange(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print "Minibatch loss at step", step, ":", l
      print "Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels)
      print "Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels)
  print "Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels)
# Out:
# Initialized
# Minibatch loss at step 0 : 2.74524
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.4%
# Minibatch loss at step 50 : 1.77332
# Minibatch accuracy: 25.0%
# Validation accuracy: 38.6%
# Minibatch loss at step 100 : 1.11084
# Minibatch accuracy: 68.8%
# Validation accuracy: 68.5%
# Minibatch loss at step 150 : 0.844778
# Minibatch accuracy: 75.0%
# Validation accuracy: 70.0%
# Minibatch loss at step 200 : 1.11837
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.5%
# Minibatch loss at step 250 : 0.929058
# Minibatch accuracy: 75.0%
# Validation accuracy: 76.9%
# Minibatch loss at step 300 : 0.845213
# Minibatch accuracy: 75.0%
# Validation accuracy: 79.1%
# Minibatch loss at step 350 : 1.35294
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.7%
# Minibatch loss at step 400 : 0.898435
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.9%
# Minibatch loss at step 450 : 0.822878
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.8%
# Minibatch loss at step 500 : 0.854203
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.4%
# Minibatch loss at step 550 : 0.922701
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.8%
# Minibatch loss at step 600 : 0.964312
# Minibatch accuracy: 68.8%
# Validation accuracy: 80.3%
# Minibatch loss at step 650 : 1.12376
# Minibatch accuracy: 62.5%
# Validation accuracy: 81.8%
# Minibatch loss at step 700 : 0.186025
# Minibatch accuracy: 93.8%
# Validation accuracy: 81.6%
# Minibatch loss at step 750 : 0.558455
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.1%
# Minibatch loss at step 800 : 0.579793
# Minibatch accuracy: 87.5%
# Validation accuracy: 81.9%
# Minibatch loss at step 850 : 0.450504
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.2%
# Minibatch loss at step 900 : 0.299257
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.1%
# Minibatch loss at step 950 : 0.427011
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.7%
# Minibatch loss at step 1000 : 0.818622
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.2%
# Test accuracy: 90.0%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size / 4 * image_size / 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, strides=[1,1,1,1], padding='SAME')
    pool = tf.nn.max_pool(conv, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(pool + layer1_biases)
    
    conv = tf.nn.conv2d(hidden, layer2_weights, strides=[1,1,1,1], padding='SAME')
    pool = tf.nn.max_pool(conv, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(pool + layer2_biases)
    
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print "Initialized"
  for step in xrange(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print "\nMinibatch loss at step", step, ":", l
      print "Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels)
      print "Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels)
  print "Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels)
# Out:
# Initialized
#
# Minibatch loss at step 0 : 3.24517
# Minibatch accuracy: 18.8%
# Validation accuracy: 10.1%
#
# Minibatch loss at step 50 : 1.2157
# Minibatch accuracy: 56.2%
# Validation accuracy: 54.6%
#
# Minibatch loss at step 100 : 1.03329
# Minibatch accuracy: 81.2%
# Validation accuracy: 71.2%
#
# Minibatch loss at step 150 : 0.914801
# Minibatch accuracy: 56.2%
# Validation accuracy: 71.6%
#
# Minibatch loss at step 200 : 1.05468
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.1%
#
# Minibatch loss at step 250 : 0.678852
# Minibatch accuracy: 81.2%
# Validation accuracy: 76.6%
#
# Minibatch loss at step 300 : 0.979864
# Minibatch accuracy: 68.8%
# Validation accuracy: 77.6%
#
# Minibatch loss at step 350 : 1.19175
# Minibatch accuracy: 75.0%
# Validation accuracy: 75.2%
#
# Minibatch loss at step 400 : 0.756097
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.6%
#
# Minibatch loss at step 450 : 0.741292
# Minibatch accuracy: 68.8%
# Validation accuracy: 76.7%
#
# Minibatch loss at step 500 : 0.630523
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.9%
#
# Minibatch loss at step 550 : 0.692397
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.6%
#
# Minibatch loss at step 600 : 1.07436
# Minibatch accuracy: 62.5%
# Validation accuracy: 81.3%
#
# Minibatch loss at step 650 : 0.897559
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.2%
#
# Minibatch loss at step 700 : 0.181167
# Minibatch accuracy: 93.8%
# Validation accuracy: 82.8%
#
# Minibatch loss at step 750 : 0.569196
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.7%
#
# Minibatch loss at step 800 : 0.804949
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.2%
#
# Minibatch loss at step 850 : 0.365131
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.5%
#
# Minibatch loss at step 900 : 0.194539
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.6%
#
# Minibatch loss at step 950 : 0.234269
# Minibatch accuracy: 100.0%
# Validation accuracy: 83.1%
#
# Minibatch loss at step 1000 : 0.714775
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.9%
# Test accuracy: 90.7%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64
SEED = 133

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  conv1_weights = tf.Variable(
      tf.truncated_normal([5, 5, num_channels, 32],  # 5x5 filter, depth 32.
                          stddev=0.1,
                          seed=SEED))
  conv1_biases = tf.Variable(tf.zeros([32]))
  
  conv2_weights = tf.Variable(
      tf.truncated_normal([5, 5, 32, 64],
                          stddev=0.1,
                          seed=SEED))
  conv2_biases = tf.Variable(tf.constant(0.1, shape=[64]))
  
  fc1_weights = tf.Variable(  # fully connected, depth 512.
      tf.truncated_normal(
          [image_size // 4 * image_size // 4 * 64, 512],
          stddev=0.1,
          seed=SEED))
  fc1_biases = tf.Variable(tf.constant(0.1, shape=[512]))
  
  fc2_weights = tf.Variable(
      tf.truncated_normal([512, num_labels],
                          stddev=0.1,
                          seed=SEED))
  fc2_biases = tf.Variable(tf.constant(0.1, shape=[num_labels]))
  
  # Model.
  def model(data, drop=False):
    conv = tf.nn.conv2d(data,
                        conv1_weights,
                        strides=[1, 1, 1, 1],
                        padding='SAME')
    # Bias and rectified linear non-linearity.
    relu = tf.nn.relu(tf.nn.bias_add(conv, conv1_biases))
    pool = tf.nn.max_pool(relu,
                          ksize=[1, 2, 2, 1],
                          strides=[1, 2, 2, 1],
                          padding='SAME')
    conv = tf.nn.conv2d(pool,
                        conv2_weights,
                        strides=[1, 1, 1, 1],
                        padding='SAME')
    relu = tf.nn.relu(tf.nn.bias_add(conv, conv2_biases))
    pool = tf.nn.max_pool(relu,
                          ksize=[1, 2, 2, 1],
                          strides=[1, 2, 2, 1],
                          padding='SAME')
    pool_shape = pool.get_shape().as_list()
    reshape = tf.reshape(
        pool,
        [pool_shape[0], pool_shape[1] * pool_shape[2] * pool_shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, fc1_weights) + fc1_biases)
    if drop:
      hidden = tf.nn.dropout(hidden, 0.5, seed=SEED)
    return tf.matmul(hidden, fc2_weights) + fc2_biases
  
  # Training computation.
  logits = model(tf_train_dataset, drop=False)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
#   optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  optimizer = tf.train.AdamOptimizer().minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 10001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print "Initialized"
  for step in xrange(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 100 == 0):
      print "\nMinibatch loss at step", step, ":", l
      print "Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels)
      print "Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels)
    if (step % 500 == 0):
      print "Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels)
# Out:
# Initialized
#
# Minibatch loss at step 0 : 4.17427
# Minibatch accuracy: 25.0%
# Validation accuracy: 13.9%
# Test accuracy: 14.1%
#
# Minibatch loss at step 100 : 0.84152
# Minibatch accuracy: 81.2%
# Validation accuracy: 79.7%
#
# Minibatch loss at step 200 : 0.910398
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.2%
#
# Minibatch loss at step 300 : 0.912907
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.8%
#
# Minibatch loss at step 400 : 0.319655
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.2%
#
# Minibatch loss at step 500 : 0.517412
# Minibatch accuracy: 75.0%
# Validation accuracy: 85.3%
# Test accuracy: 92.0%
#
# Minibatch loss at step 600 : 0.642291
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.0%
#
# Minibatch loss at step 700 : 0.126858
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.5%
#
# Minibatch loss at step 800 : 0.667795
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.0%
#
# Minibatch loss at step 900 : 0.128797
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.0%
#
# Minibatch loss at step 1000 : 0.594312
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.5%
# Test accuracy: 91.9%
#
# Minibatch loss at step 1100 : 0.0505896
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.7%
#
# Minibatch loss at step 1200 : 0.580678
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.6%
#
# Minibatch loss at step 1300 : 0.580422
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.4%
#
# Minibatch loss at step 1400 : 0.164193
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.1%
#
# Minibatch loss at step 1500 : 0.40237
# Minibatch accuracy: 87.5%
# Validation accuracy: 86.7%
# Test accuracy: 92.9%
#
# Minibatch loss at step 1600 : 0.140533
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.3%
#
# Minibatch loss at step 1700 : 0.665526
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.0%
#
# Minibatch loss at step 1800 : 0.0381147
# Minibatch accuracy: 100.0%
# Validation accuracy: 87.2%
#
# Minibatch loss at step 1900 : 0.553259
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.3%
#
# Minibatch loss at step 2000 : 0.792787
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.3%
# Test accuracy: 94.4%
#
# Minibatch loss at step 2100 : 0.471341
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.4%
#
# Minibatch loss at step 2200 : 0.105151
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.5%
#
# Minibatch loss at step 2300 : 0.268069
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
#
# Minibatch loss at step 2400 : 0.0840758
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.4%
#
# Minibatch loss at step 2500 : 0.735507
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.2%
# Test accuracy: 94.2%
#
# Minibatch loss at step 2600 : 0.69638
# Minibatch accuracy: 75.0%
# Validation accuracy: 88.3%
#
# Minibatch loss at step 2700 : 0.38378
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.1%
#
# Minibatch loss at step 2800 : 0.302966
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
#
# Minibatch loss at step 2900 : 0.704426
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.1%
#
# Minibatch loss at step 3000 : 0.15322
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.8%
# Test accuracy: 94.6%
#
# Minibatch loss at step 3100 : 0.172927
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.9%
#
# Minibatch loss at step 3200 : 0.245291
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.7%
#
# Minibatch loss at step 3300 : 0.671229
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
#
# Minibatch loss at step 3400 : 0.409478
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.5%
#
# Minibatch loss at step 3500 : 0.367452
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Test accuracy: 94.3%
#
# Minibatch loss at step 3600 : 0.499788
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.2%
#
# Minibatch loss at step 3700 : 0.00359405
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.4%
#
# Minibatch loss at step 3800 : 0.414231
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.1%
#
# Minibatch loss at step 3900 : 0.0478882
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
#
# Minibatch loss at step 4000 : 0.547231
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.4%
# Test accuracy: 95.2%
#
# Minibatch loss at step 4100 : 0.768368
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.2%
#
# Minibatch loss at step 4200 : 0.494429
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.8%
#
# Minibatch loss at step 4300 : 0.0999508
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
#
# Minibatch loss at step 4400 : 0.457506
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.5%
#
# Minibatch loss at step 4500 : 0.367771
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# Test accuracy: 95.0%
#
# Minibatch loss at step 4600 : 0.45738
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
#
# Minibatch loss at step 4700 : 0.631094
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.6%
#
# Minibatch loss at step 4800 : 0.352478
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.7%
#
# Minibatch loss at step 4900 : 0.209305
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
#
# Minibatch loss at step 5000 : 0.208206
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.8%
# Test accuracy: 95.5%
#
# Minibatch loss at step 5100 : 0.0445011
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.7%
#
# Minibatch loss at step 5200 : 0.588069
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.8%
#
# Minibatch loss at step 5300 : 0.332191
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
#
# Minibatch loss at step 5400 : 0.295145
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.0%
#
# Minibatch loss at step 5500 : 0.302774
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.9%
# Test accuracy: 95.3%
#
# Minibatch loss at step 5600 : 0.666212
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.1%
#
# Minibatch loss at step 5700 : 0.130986
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.0%
#
# Minibatch loss at step 5800 : 0.280109
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.1%
#
# Minibatch loss at step 5900 : 0.478708
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.0%
#
# Minibatch loss at step 6000 : 0.335612
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.2%
# Test accuracy: 95.6%
#
# Minibatch loss at step 6100 : 0.239191
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.0%
#
# Minibatch loss at step 6200 : 0.309221
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
#
# Minibatch loss at step 6300 : 0.600453
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.6%
#
# Minibatch loss at step 6400 : 0.158793
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.5%
#
# Minibatch loss at step 6500 : 0.327602
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.4%
# Test accuracy: 95.2%
#
# Minibatch loss at step 6600 : 0.221228
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
#
# Minibatch loss at step 6700 : 0.639847
# Minibatch accuracy: 75.0%
# Validation accuracy: 90.0%
#
# Minibatch loss at step 6800 : 0.916373
# Minibatch accuracy: 75.0%
# Validation accuracy: 90.1%
#
# Minibatch loss at step 6900 : 0.434058
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.8%
#
# Minibatch loss at step 7000 : 0.346917
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.3%
# Test accuracy: 95.6%
#
# Minibatch loss at step 7100 : 0.0243869
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
#
# Minibatch loss at step 7200 : 0.101448
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.9%
#
# Minibatch loss at step 7300 : 0.707874
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.4%
#
# Minibatch loss at step 7400 : 0.341974
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.3%
#
# Minibatch loss at step 7500 : 0.664901
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Test accuracy: 95.9%
#
# Minibatch loss at step 7600 : 0.383676
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.0%
#
# Minibatch loss at step 7700 : 0.408044
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
#
# Minibatch loss at step 7800 : 0.172934
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.3%
#
# Minibatch loss at step 7900 : 0.260861
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.6%
#
# Minibatch loss at step 8000 : 0.0898428
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.9%
# Test accuracy: 96.0%
#
# Minibatch loss at step 8100 : 0.473572
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
#
# Minibatch loss at step 8200 : 0.322143
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
#
# Minibatch loss at step 8300 : 0.0115446
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.3%
#
# Minibatch loss at step 8400 : 0.510583
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.5%
#
# Minibatch loss at step 8500 : 0.211555
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.6%
# Test accuracy: 96.0%
#
# Minibatch loss at step 8600 : 0.358342
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.9%
#
# Minibatch loss at step 8700 : 0.160062
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.8%
#
# Minibatch loss at step 8800 : 0.403991
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.7%
#
# Minibatch loss at step 8900 : 0.564259
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.7%
#
# Minibatch loss at step 9000 : 0.563928
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.5%
# Test accuracy: 96.1%
#
# Minibatch loss at step 9100 : 0.20827
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.8%
#
# Minibatch loss at step 9200 : 0.229505
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.4%
#
# Minibatch loss at step 9300 : 0.166717
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.5%
#
# Minibatch loss at step 9400 : 0.291272
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.8%
#
# Minibatch loss at step 9500 : 0.0459559
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.8%
# Test accuracy: 96.3%
#
# Minibatch loss at step 9600 : 0.39594
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.9%
#
# Minibatch loss at step 9700 : 0.159786
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.6%
#
# Minibatch loss at step 9800 : 0.313745
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.7%
#
# Minibatch loss at step 9900 : 0.610087
# Minibatch accuracy: 81.2%
# Validation accuracy: 91.0%
#
# Minibatch loss at step 10000 : 0.324511
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.8%
# Test accuracy: 96.0%
