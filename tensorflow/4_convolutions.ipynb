# %% [markdown]
# Deep Learning
# =============
#
# Assignment 4
# ------------
#
# Previously in `2_fullyconnected.ipynb` and `3_regularization.ipynb`, we trained fully connected networks to classify [notMNIST](http://yaroslavvb.blogspot.com/2011/09/notmnist-dataset.html) characters.
#
# The goal of this assignment is make the neural network convolutional.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
import cPickle as pickle
import numpy as np
import tensorflow as tf

# %%
pickle_file = 'notMNIST.pickle'

with open(pickle_file, 'rb') as f:
  save = pickle.load(f)
  train_dataset = save['train_dataset']
  train_labels = save['train_labels']
  valid_dataset = save['valid_dataset']
  valid_labels = save['valid_labels']
  test_dataset = save['test_dataset']
  test_labels = save['test_labels']
  del save  # hint to help gc free up memory
  print 'Training set', train_dataset.shape, train_labels.shape
  print 'Validation set', valid_dataset.shape, valid_labels.shape
  print 'Test set', test_dataset.shape, test_labels.shape
# Out:
# Training set (529114, 28, 28) (529114,)
# Validation set (10000, 28, 28) (10000,)
# Test set (18724, 28, 28) (18724,)

# %% [markdown]
# Reformat into a TensorFlow-friendly shape:
# - convolutions need the image data formatted as a cube (width by height by #channels)
# - labels as float 1-hot encodings.

# %%
image_size = 28
num_labels = 10
num_channels = 1 # grayscale

import numpy as np

def reformat(dataset, labels):
  dataset = dataset.reshape(
    (-1, image_size, image_size, num_channels)).astype(np.float32)
  labels = (np.arange(num_labels) == labels[:,None]).astype(np.float32)
  return dataset, labels
train_dataset, train_labels = reformat(train_dataset, train_labels)
valid_dataset, valid_labels = reformat(valid_dataset, valid_labels)
test_dataset, test_labels = reformat(test_dataset, test_labels)
print 'Training set', train_dataset.shape, train_labels.shape
print 'Validation set', valid_dataset.shape, valid_labels.shape
print 'Test set', test_dataset.shape, test_labels.shape
# Out:
# Training set (529114, 28, 28, 1) (529114, 10)
# Validation set (10000, 28, 28, 1) (10000, 10)
# Test set (18724, 28, 28, 1) (18724, 10)

# %%
def accuracy(predictions, labels):
  return (100.0 * np.sum(np.argmax(predictions, 1) == np.argmax(labels, 1))
          / predictions.shape[0])

# %% [markdown]
# Let's build a small network with two convolutional layers, followed by one fully connected layer. Convolutional networks are more expensive computationally, so we'll limit its depth and number of fully connected nodes.

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size / 4 * image_size / 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer1_biases)
    conv = tf.nn.conv2d(hidden, layer2_weights, [1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(conv + layer2_biases)
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print "Initialized"
  for step in xrange(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print "Minibatch loss at step", step, ":", l
      print "Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels)
      print "Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels)
  print "Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels)
# Out:
# Initialized
# Minibatch loss at step 0 : 4.05382
# Minibatch accuracy: 0.0%
# Validation accuracy: 9.6%
# Minibatch loss at step 50 : 1.6508
# Minibatch accuracy: 37.5%
# Validation accuracy: 60.3%
# Minibatch loss at step 100 : 1.13064
# Minibatch accuracy: 75.0%
# Validation accuracy: 65.0%
# Minibatch loss at step 150 : 1.88577
# Minibatch accuracy: 50.0%
# Validation accuracy: 74.6%
# Minibatch loss at step 200 : 0.914192
# Minibatch accuracy: 75.0%
# Validation accuracy: 77.1%
# Minibatch loss at step 250 : 1.11783
# Minibatch accuracy: 75.0%
# Validation accuracy: 78.7%
# Minibatch loss at step 300 : 0.373946
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.1%
# Minibatch loss at step 350 : 0.666575
# Minibatch accuracy: 75.0%
# Validation accuracy: 80.7%
# Minibatch loss at step 400 : 0.228214
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.2%
# Minibatch loss at step 450 : 0.604123
# Minibatch accuracy: 81.2%
# Validation accuracy: 80.9%
# Minibatch loss at step 500 : 1.35885
# Minibatch accuracy: 56.2%
# Validation accuracy: 81.4%
# Minibatch loss at step 550 : 0.968971
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.1%
# Minibatch loss at step 600 : 0.976123
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 650 : 0.573389
# Minibatch accuracy: 87.5%
# Validation accuracy: 82.2%
# Minibatch loss at step 700 : 0.550376
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.2%
# Minibatch loss at step 750 : 0.521149
# Minibatch accuracy: 81.2%
# Validation accuracy: 82.3%
# Minibatch loss at step 800 : 0.642003
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 850 : 0.666651
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.6%
# Minibatch loss at step 900 : 0.720413
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.9%
# Minibatch loss at step 950 : 0.573963
# Minibatch accuracy: 93.8%
# Validation accuracy: 83.6%
# Minibatch loss at step 1000 : 0.541583
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.1%
# Test accuracy: 89.4%

# %% [markdown]
# ---
# Problem 1
# ---------
#
# The convolutional model above uses convolutions with stride 2 to reduce the dimensionality. Replace the strides a max pooling operation (`nn.max_pool()`) of stride 2 and kernel size 2.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size / 4 * image_size / 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, strides=[1,1,1,1], padding='SAME')
    pool = tf.nn.max_pool(conv, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(pool + layer1_biases)
    
    conv = tf.nn.conv2d(hidden, layer2_weights, strides=[1,1,1,1], padding='SAME')
    pool = tf.nn.max_pool(conv, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(pool + layer2_biases)
    
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
  optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 1001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print "Initialized"
  for step in xrange(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 50 == 0):
      print "\nMinibatch loss at step", step, ":", l
      print "Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels)
      print "Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels)
  print "Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels)
# Out:
# Initialized
# Minibatch loss at step 0 : 4.38182
# Minibatch accuracy: 6.2%
# Validation accuracy: 10.1%
# Minibatch loss at step 50 : 1.76801
# Minibatch accuracy: 43.8%
# Validation accuracy: 34.0%
# Minibatch loss at step 100 : 1.41699
# Minibatch accuracy: 62.5%
# Validation accuracy: 55.3%
# Minibatch loss at step 150 : 1.74261
# Minibatch accuracy: 50.0%
# Validation accuracy: 69.5%
# Minibatch loss at step 200 : 0.978656
# Minibatch accuracy: 68.8%
# Validation accuracy: 75.9%
# Minibatch loss at step 250 : 0.909534
# Minibatch accuracy: 68.8%
# Validation accuracy: 79.2%
# Minibatch loss at step 300 : 0.304199
# Minibatch accuracy: 87.5%
# Validation accuracy: 80.7%
# Minibatch loss at step 350 : 0.588288
# Minibatch accuracy: 81.2%
# Validation accuracy: 81.7%
# Minibatch loss at step 400 : 0.233492
# Minibatch accuracy: 100.0%
# Validation accuracy: 81.7%
# Minibatch loss at step 450 : 0.590579
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.2%
# Minibatch loss at step 500 : 1.22498
# Minibatch accuracy: 56.2%
# Validation accuracy: 83.0%
# Minibatch loss at step 550 : 1.01284
# Minibatch accuracy: 68.8%
# Validation accuracy: 82.2%
# Minibatch loss at step 600 : 0.905224
# Minibatch accuracy: 75.0%
# Validation accuracy: 82.0%
# Minibatch loss at step 650 : 0.579546
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.7%
# Minibatch loss at step 700 : 0.564162
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.2%
# Minibatch loss at step 750 : 0.428467
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.2%
# Minibatch loss at step 800 : 0.697621
# Minibatch accuracy: 81.2%
# Validation accuracy: 83.5%
# Minibatch loss at step 850 : 0.626583
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.5%
# Minibatch loss at step 900 : 0.721499
# Minibatch accuracy: 75.0%
# Validation accuracy: 83.9%
# Minibatch loss at step 950 : 0.73733
# Minibatch accuracy: 68.8%
# Validation accuracy: 84.7%
# Minibatch loss at step 1000 : 0.436383
# Minibatch accuracy: 87.5%
# Validation accuracy: 84.9%
# Test accuracy: 90.8%

# %% [markdown]
# ---
# Problem 2
# ---------
#
# Try to get the best performance you can using a convolutional net. Look for example at the classic [LeNet5](http://yann.lecun.com/exdb/lenet/) architecture, adding Dropout, and/or adding learning rate decay.
#
# ---

# %%
batch_size = 16
patch_size = 5
depth = 16
num_hidden = 64

graph = tf.Graph()

with graph.as_default():

  # Input data.
  tf_train_dataset = tf.placeholder(tf.float32, shape=(batch_size, image_size, image_size, num_channels))
  tf_train_labels = tf.placeholder(tf.float32, shape=(batch_size, num_labels))
  tf_valid_dataset = tf.constant(valid_dataset)
  tf_test_dataset = tf.constant(test_dataset)
  
  # Variables.
  layer1_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, num_channels, depth], stddev=0.1))
  layer1_biases = tf.Variable(tf.zeros([depth]))
  
  layer2_weights = tf.Variable(tf.truncated_normal(
      [patch_size, patch_size, depth, depth], stddev=0.1))
  layer2_biases = tf.Variable(tf.constant(1.0, shape=[depth]))
  
  layer3_weights = tf.Variable(tf.truncated_normal(
      [image_size / 4 * image_size / 4 * depth, num_hidden], stddev=0.1))
  layer3_biases = tf.Variable(tf.constant(1.0, shape=[num_hidden]))
  
  layer4_weights = tf.Variable(tf.truncated_normal(
      [num_hidden, num_labels], stddev=0.1))
  layer4_biases = tf.Variable(tf.constant(1.0, shape=[num_labels]))
  
  # Model.
  def model(data):
    conv = tf.nn.conv2d(data, layer1_weights, strides=[1,1,1,1], padding='SAME')
    pool = tf.nn.max_pool(conv, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(pool + layer1_biases)
    
    conv = tf.nn.conv2d(hidden, layer2_weights, strides=[1,1,1,1], padding='SAME')
    pool = tf.nn.max_pool(conv, ksize=[1, 2, 2, 1], strides=[1, 2, 2, 1], padding='SAME')
    hidden = tf.nn.relu(pool + layer2_biases)
    
    shape = hidden.get_shape().as_list()
    reshape = tf.reshape(hidden, [shape[0], shape[1] * shape[2] * shape[3]])
    hidden = tf.nn.relu(tf.matmul(reshape, layer3_weights) + layer3_biases)
    return tf.matmul(hidden, layer4_weights) + layer4_biases
  
  # Training computation.
  logits = model(tf_train_dataset)
  loss = tf.reduce_mean(
    tf.nn.softmax_cross_entropy_with_logits(logits, tf_train_labels))
    
  # Optimizer.
#   optimizer = tf.train.GradientDescentOptimizer(0.05).minimize(loss)
  optimizer = tf.train.AdamOptimizer().minimize(loss)
  
  # Predictions for the training, validation, and test data.
  train_prediction = tf.nn.softmax(logits)
  valid_prediction = tf.nn.softmax(model(tf_valid_dataset))
  test_prediction = tf.nn.softmax(model(tf_test_dataset))

# %%
num_steps = 10001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print "Initialized"
  for step in xrange(num_steps):
    offset = (step * batch_size) % (train_labels.shape[0] - batch_size)
    batch_data = train_dataset[offset:(offset + batch_size), :, :, :]
    batch_labels = train_labels[offset:(offset + batch_size), :]
    feed_dict = {tf_train_dataset : batch_data, tf_train_labels : batch_labels}
    _, l, predictions = session.run(
      [optimizer, loss, train_prediction], feed_dict=feed_dict)
    if (step % 200 == 0):
      print "\nMinibatch loss at step", step, ":", l
      print "Minibatch accuracy: %.1f%%" % accuracy(predictions, batch_labels)
      print "Validation accuracy: %.1f%%" % accuracy(
        valid_prediction.eval(), valid_labels)
      print "Test accuracy: %.1f%%" % accuracy(test_prediction.eval(), test_labels)
# Out:
# Initialized
#
# Minibatch loss at step 0 : 3.83668
# Minibatch accuracy: 0.0%
# Validation accuracy: 9.9%
# Test accuracy: 9.8%
#
# Minibatch loss at step 200 : 0.797021
# Minibatch accuracy: 81.2%
# Validation accuracy: 77.6%
# Test accuracy: 84.2%
#
# Minibatch loss at step 400 : 0.19883
# Minibatch accuracy: 93.8%
# Validation accuracy: 80.5%
# Test accuracy: 86.7%
#
# Minibatch loss at step 600 : 1.34269
# Minibatch accuracy: 68.8%
# Validation accuracy: 81.4%
# Test accuracy: 88.0%
#
# Minibatch loss at step 800 : 0.768797
# Minibatch accuracy: 87.5%
# Validation accuracy: 83.4%
# Test accuracy: 89.1%
#
# Minibatch loss at step 1000 : 0.549907
# Minibatch accuracy: 75.0%
# Validation accuracy: 84.8%
# Test accuracy: 90.7%
#
# Minibatch loss at step 1200 : 0.385657
# Minibatch accuracy: 81.2%
# Validation accuracy: 84.6%
# Test accuracy: 90.6%
#
# Minibatch loss at step 1400 : 0.468739
# Minibatch accuracy: 81.2%
# Validation accuracy: 85.6%
# Test accuracy: 91.7%
#
# Minibatch loss at step 1600 : 0.412134
# Minibatch accuracy: 81.2%
# Validation accuracy: 86.4%
# Test accuracy: 91.8%
#
# Minibatch loss at step 1800 : 0.144995
# Minibatch accuracy: 100.0%
# Validation accuracy: 86.7%
# Test accuracy: 92.5%
#
# Minibatch loss at step 2000 : 0.797576
# Minibatch accuracy: 75.0%
# Validation accuracy: 86.9%
# Test accuracy: 92.9%
#
# Minibatch loss at step 2200 : 0.512315
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.2%
# Test accuracy: 93.0%
#
# Minibatch loss at step 2400 : 0.134927
# Minibatch accuracy: 93.8%
# Validation accuracy: 86.8%
# Test accuracy: 92.7%
#
# Minibatch loss at step 2600 : 0.747754
# Minibatch accuracy: 81.2%
# Validation accuracy: 87.1%
# Test accuracy: 93.0%
#
# Minibatch loss at step 2800 : 0.241983
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.5%
# Test accuracy: 93.1%
#
# Minibatch loss at step 3000 : 0.323146
# Minibatch accuracy: 93.8%
# Validation accuracy: 87.4%
# Test accuracy: 93.3%
#
# Minibatch loss at step 3200 : 0.171953
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.0%
# Test accuracy: 93.4%
#
# Minibatch loss at step 3400 : 0.504074
# Minibatch accuracy: 93.8%
# Validation accuracy: 88.4%
# Test accuracy: 93.7%
#
# Minibatch loss at step 3600 : 0.355398
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# Test accuracy: 93.7%
#
# Minibatch loss at step 3800 : 0.410824
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.0%
# Test accuracy: 93.5%
#
# Minibatch loss at step 4000 : 0.503574
# Minibatch accuracy: 81.2%
# Validation accuracy: 88.3%
# Test accuracy: 93.7%
#
# Minibatch loss at step 4200 : 0.474172
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.3%
# Test accuracy: 93.9%
#
# Minibatch loss at step 4400 : 0.461174
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.7%
# Test accuracy: 94.0%
#
# Minibatch loss at step 4600 : 0.415411
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.5%
# Test accuracy: 93.9%
#
# Minibatch loss at step 4800 : 0.656395
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.6%
# Test accuracy: 94.1%
#
# Minibatch loss at step 5000 : 0.723749
# Minibatch accuracy: 87.5%
# Validation accuracy: 88.9%
# Test accuracy: 94.1%
#
# Minibatch loss at step 5200 : 0.0303707
# Minibatch accuracy: 100.0%
# Validation accuracy: 88.9%
# Test accuracy: 94.2%
#
# Minibatch loss at step 5400 : 0.699938
# Minibatch accuracy: 68.8%
# Validation accuracy: 89.0%
# Test accuracy: 94.3%
#
# Minibatch loss at step 5600 : 0.313493
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.0%
# Test accuracy: 94.4%
#
# Minibatch loss at step 5800 : 0.689135
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.2%
# Test accuracy: 94.4%
#
# Minibatch loss at step 6000 : 0.208515
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# Test accuracy: 94.4%
#
# Minibatch loss at step 6200 : 0.614954
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.0%
# Test accuracy: 94.4%
#
# Minibatch loss at step 6400 : 0.0281126
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.3%
# Test accuracy: 94.4%
#
# Minibatch loss at step 6600 : 0.301197
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# Test accuracy: 94.8%
#
# Minibatch loss at step 6800 : 0.311185
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.4%
# Test accuracy: 94.4%
#
# Minibatch loss at step 7000 : 0.266031
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.6%
# Test accuracy: 94.7%
#
# Minibatch loss at step 7200 : 0.470631
# Minibatch accuracy: 81.2%
# Validation accuracy: 89.6%
# Test accuracy: 94.6%
#
# Minibatch loss at step 7400 : 0.189895
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# Test accuracy: 94.6%
#
# Minibatch loss at step 7600 : 0.205503
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.3%
# Test accuracy: 94.5%
#
# Minibatch loss at step 7800 : 0.276461
# Minibatch accuracy: 87.5%
# Validation accuracy: 89.8%
# Test accuracy: 94.8%
#
# Minibatch loss at step 8000 : 0.697305
# Minibatch accuracy: 75.0%
# Validation accuracy: 89.7%
# Test accuracy: 94.5%
#
# Minibatch loss at step 8200 : 0.130368
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.9%
# Test accuracy: 94.7%
#
# Minibatch loss at step 8400 : 0.0921689
# Minibatch accuracy: 100.0%
# Validation accuracy: 89.8%
# Test accuracy: 94.8%
#
# Minibatch loss at step 8600 : 0.198089
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.8%
# Test accuracy: 94.8%
#
# Minibatch loss at step 8800 : 1.17914
# Minibatch accuracy: 62.5%
# Validation accuracy: 89.4%
# Test accuracy: 94.4%
#
# Minibatch loss at step 9000 : 0.35891
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.0%
# Test accuracy: 94.8%
#
# Minibatch loss at step 9200 : 0.173149
# Minibatch accuracy: 93.8%
# Validation accuracy: 90.0%
# Test accuracy: 95.1%
#
# Minibatch loss at step 9400 : 0.549885
# Minibatch accuracy: 81.2%
# Validation accuracy: 90.2%
# Test accuracy: 94.8%
#
# Minibatch loss at step 9600 : 0.244332
# Minibatch accuracy: 93.8%
# Validation accuracy: 89.7%
# Test accuracy: 94.8%
#
# Minibatch loss at step 9800 : 0.370749
# Minibatch accuracy: 87.5%
# Validation accuracy: 90.1%
# Test accuracy: 95.0%
#
# Minibatch loss at step 10000 : 0.0996886
# Minibatch accuracy: 100.0%
# Validation accuracy: 90.2%
# Test accuracy: 95.0%
